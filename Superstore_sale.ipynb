# %% [markdown]
# # SUPER STORE SALE ANALYSIS

# %%
import pandas as pd

# %%
s=pd.read_csv(r"C:\Users\LENOVO\OneDrive\Desktop\SQL_PRACTICE\Superstore-Sales-Analysis-main\Superstore-Sales-Analysis-main\superstore datasets\datasets\superstore dataset.csv")
s
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
s.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
s.drop_duplicates(inplace=True)
s.head(10)
s
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
# drop rows where ship date is earlier than order date
d = s[s['Ship Date'] >= s['Order Date']].index
s
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
s.sort_values(by=['Order Date'])
s
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
d=s.to_csv(r"E:\ANISH V\Downloads\Sales_data.csv")
d
